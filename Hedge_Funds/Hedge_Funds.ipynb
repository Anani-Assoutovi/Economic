# %% [markdown]
# [Data Source](https://www.kaggle.com/datasets/yousefsaeedian/edhec-investment-management-datasets)

# %% [markdown]
# # Understanding Hedge Funds Investments

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("yousefsaeedian/edhec-investment-management-datasets")

#print("Path to dataset files:", path)

# %%
# !ls -lh ~/.cache/kagglehub/datasets/yousefsaeedian/edhec-investment-management-datasets/versions/17
# Out:
# total 11336
# -rw-r--r--  1 ananiassoutovi  staff    34K May 12 17:25 Assets_7.csv
# -rw-r--r--  1 ananiassoutovi  staff   772K May 12 17:25 BRK-A.csv
# -rw-r--r--  1 ananiassoutovi  staff   225K May 12 17:25 brka_d_ret.csv
# -rw-r--r--  1 ananiassoutovi  staff    38K May 12 17:25 Data_Oct2018_v2.csv
# -rw-r--r--  1 ananiassoutovi  staff    72K May 12 17:25 edhec_risk_kit.py
# -rw-r--r--  1 ananiassoutovi  staff    21K May 12 17:25 edhec-hedgefundindices.csv
# -rw-r--r--  1 ananiassoutovi  staff   1.0M May 12 17:25 F-F_Research_Data_Factors_daily.CSV
# -rw-r--r--  1 ananiassoutovi  staff    47K May 12 17:25 F-F_Research_Data_Factors_m.csv
# -rw-r--r--  1 ananiassoutovi  staff    52K May 12 17:25 F-F_Research_Data_Factors.CSV
# -rw-r--r--  1 ananiassoutovi  staff   269K May 12 17:25 ind30_m_ew_rets.csv
# -rw-r--r--  1 ananiassoutovi  staff   268K May 12 17:25 ind30_m_nfirms.csv
# -rw-r--r--  1 ananiassoutovi  staff   365K May 12 17:25 ind30_m_size.csv
# ...

# %%
import pandas as pd

# %%
path = f'{path}/ind49_m_nfirms.csv'

df = pd.read_csv(path)

df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1110 entries, 0 to 1109
# Data columns (total 50 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1110 non-null   int64
#  1   Agric       1110 non-null   int64
#  2   Food        1110 non-null   int64
#  3   Soda        1110 non-null   int64
#  4   Beer        1110 non-null   int64
#  5   Smoke       1110 non-null   int64
#  6   Toys        1110 non-null   int64
#  7   Fun         1110 non-null   int64
#  8   Books       1110 non-null   int64
#  9   Hshld       1110 non-null   int64
#  10  Clths       1110 non-null   int64
#  11  Hlth        1110 non-null   int64
#  12  MedEq       1110 non-null   int64
#  13  Drugs       1110 non-null   int64
#  14  Chems       1110 non-null   int64
#  15  Rubbr       1110 non-null   int64
#  16  Txtls       1110 non-null   int64
#  17  BldMt       1110 non-null   int64
#  18  Cnstr       1110 non-null   int64
# ...
